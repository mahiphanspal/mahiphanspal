# %% [markdown]
# <a href="https://colab.research.google.com/github/mahiphanspal/mahiphanspal/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
4+4
# Out:
# 8

# %%
import torch
